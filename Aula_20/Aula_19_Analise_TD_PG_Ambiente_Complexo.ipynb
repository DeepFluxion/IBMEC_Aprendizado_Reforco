# %% [markdown]
# # Experimentos de Aprendizado por Reforço em Cliff World 10x10
#
# Este notebook apresenta uma comparação completa entre algoritmos clássicos de RL (baseados em valor) e algoritmos de gradiente de política, aplicados a um ambiente Cliff World 10x10 com características desafiadoras.
#
# ---
#
# ## 📚 Sumário
#
# 1. [Configuração do Ambiente](#1-configuração-do-ambiente)
# 2. [SARSA - State-Action-Reward-State-Action](#2-sarsa)
# 3. [Q-Learning](#3-q-learning)
# 4. [Expected SARSA](#4-expected-sarsa)
# 5. [REINFORCE - Monte Carlo Policy Gradient](#5-reinforce)
# 6. [REINFORCE com Baseline](#6-reinforce-com-baseline)
# 7. [Actor-Critic (One-Step)](#7-actor-critic)
# 8. [Comparação Final](#8-comparação-final)
#
# ---

# %%
## 1. Configuração do Ambiente

### 1.1 Imports Necessários


import numpy as np
import matplotlib.pyplot as plt
from environment import create_custom_gridworld, print_gridworld_info
from algorithms import sarsa, q_learning, expected_sarsa, get_greedy_policy
from algorithms_extended import reinforce, reinforce_baseline, actor_critic
from visualization import (visualize_gridworld, visualize_q_values, 
                           plot_learning_curves, compare_algorithms)
from visualization_extended import (visualize_stochastic_policy, plot_policy_arrows,
                                   plot_policy_gradient_learning, plot_value_and_policy)

# Configurações para reprodutibilidade
np.random.seed(42)

#plt.style.use('seaborn-v0_8-darkgrid')

# %% [markdown]
# ### 1.2 Criação do Cliff World 10x10
#
# **Descrição do Ambiente:**
#
# O Cliff World é um ambiente clássico de RL que testa a capacidade dos algoritmos de encontrar caminhos seguros versus caminhos ótimos. Nosso ambiente 10x10 possui:
#
# - **Estado inicial (S)**: Canto inferior esquerdo `(9, 0)`
# - **Estado objetivo (G)**: Canto inferior direito `(9, 9)`
# - **Abismos (C)**: Toda a linha inferior entre S e G `(9, 1)` até `(9, 8)`
# - **Recompensas**:
#   - Cair no abismo: **-100**
#   - Alcançar objetivo: **+10**
#   - Cada passo: **-1** (incentiva caminhos curtos)
#
# **Layout:**
# ```
# [ ][ ][ ][ ][ ][ ][ ][ ][ ][ ]
# [ ][ ][ ][ ][ ][ ][ ][ ][ ][ ]
# [ ][ ][ ][ ][ ][ ][ ][ ][ ][ ]
# [ ][ ][ ][ ][ ][ ][ ][ ][ ][ ]
# [ ][ ][ ][ ][ ][ ][ ][ ][ ][ ]
# [ ][ ][ ][ ][ ][ ][ ][ ][ ][ ]
# [ ][ ][ ][ ][ ][ ][ ][ ][ ][ ]
# [ ][ ][ ][ ][ ][ ][ ][ ][ ][ ]
# [ ][ ][ ][ ][ ][ ][ ][ ][ ][ ]
# [S][C][C][C][C][C][C][C][C][G]
# ```

# %%
# Cria ambiente Cliff World 10x10
gw = create_custom_gridworld(
    rows=6,
    cols=10,
    walls=[
          (3,1),(2,2),
          (3,3),(2,4),
          (3,5),(2,6),
          (3,7),(2,8),
          ],  # Sem paredes internas
    terminals={
        # Abismos na última linha (exceto cantos)
        **{(5, col): -10.0 for col in range(1, 9)},
        # Abismos na primeira linha (exceto cantos)
        **{(0, col): -50.0 for col in range(1, 9)},
        # Objetivo no canto inferior direito
        (5, 9): 10.0,
        (0, 9): 10.0
    },
    gamma=0.99,
    noise=0.1,  # Determinístico
    living_reward=-1.0
)

# Exibe informações
print_gridworld_info(gw)
# Out:
# ======================================================================
# INFORMAÇÕES DO GRIDWORLD
# ======================================================================
# Dimensões: 6 linhas x 10 colunas
# Total de estados: 52
# Paredes: 8
# Estados terminais: 18
# Fator de desconto (γ): 0.99
# Ruído: 0.1
# Living reward: -1.0
# Ações disponíveis: ['N', 'S', 'L', 'O']
#
# Paredes: [(2, 2), (2, 4), (2, 6), (2, 8), (3, 1), (3, 3), (3, 5), (3, 7)]
#
# Estados terminais:
#   (0, 1): reward = -50.0
#   (0, 2): reward = -50.0
#   (0, 3): reward = -50.0
#   (0, 4): reward = -50.0
#   (0, 5): reward = -50.0
#   (0, 6): reward = -50.0
#   (0, 7): reward = -50.0
#   (0, 8): reward = -50.0
#   (0, 9): reward = 10.0
#   (5, 1): reward = -10.0
#   (5, 2): reward = -10.0
#   (5, 3): reward = -10.0
#   (5, 4): reward = -10.0
#   (5, 5): reward = -10.0
#   (5, 6): reward = -10.0
#   (5, 7): reward = -10.0
#   (5, 8): reward = -10.0
#   (5, 9): reward = 10.0
# ======================================================================

# %%
### 1.3 Visualização do Ambiente


# Visualiza o ambiente
visualize_gridworld(
    gw,
    title="Cliff World 6x10 - Ambiente",
    figsize=(10, 10)
)

# %% [markdown]
# **Ponto de partida típico para treinamento:**
#
# ```python
# # Define estado inicial fixo para todos os experimentos
# INITIAL_STATE = (9, 0)  # Canto inferior esquerdo
#
# print(f"Estado inicial: {INITIAL_STATE}")
# print(f"Estado objetivo: (9, 9)")
# print(f"Número de abismos: {len([s for s in gw.terminal_states if gw.terminal_states[s] < 0])}")
# ```

# %%
# Define estado inicial fixo para todos os experimentos
INITIAL_STATE = (5, 0)  # Canto inferior esquerdo

print(f"Estado inicial: {INITIAL_STATE}")
print(f"Estados objetivos: (5, 9)")
print(f"Número de abismos: {len([s for s in gw.terminal_states if gw.terminal_states[s] < 0])}")
# Out:
# Estado inicial: (5, 0)
# Estados objetivos: (5, 9)
# Número de abismos: 16

# %% [markdown]
# ## 2. SARSA - State-Action-Reward-State-Action
#
# ### 2.1 Intuição
#
# **SARSA** é um algoritmo **on-policy** de Temporal Difference (TD). Ele aprende o valor $Q(s,a)$ da política que está **atualmente seguindo** (incluindo a exploração $\epsilon$-greedy).
#
# **Características:**
# - ✅ Conservador: aprende políticas mais seguras
# - ✅ Considera a exploração durante o aprendizado
# - ❌ Pode ser mais lento para convergir
# - 📊 Ideal quando a exploração tem custos reais
#
# ### 2.2 Pseudocódigo
#
# ```
# Inicializar Q(s,a) arbitrariamente
# Para cada episódio:
#     S ← estado inicial
#     A ← ação escolhida por ε-greedy usando Q
#
#     Repetir para cada passo do episódio:
#         Executar ação A, observar R, S'
#         A' ← ação escolhida por ε-greedy usando Q (do próximo estado)
#
#         Q(S,A) ← Q(S,A) + α[R + γQ(S',A') - Q(S,A)]
#
#         S ← S'
#         A ← A'
#     até S ser terminal
# ```
#
# ### 2.3 Equação de Atualização
#
# $$Q(S_t, A_t) \leftarrow Q(S_t, A_t) + \alpha \left[ R_{t+1} + \gamma Q(S_{t+1}, A_{t+1}) - Q(S_t, A_t) \right]$$
#
# **Nota importante:** O algoritmo usa $Q(S_{t+1}, A_{t+1})$ onde $A_{t+1}$ é escolhida pela política atual (ε-greedy), não pela política gulosa.

# %%
### 2.4 Treinamento do SARSA

print("="*80)
print("TREINANDO SARSA")
print("="*80)

# Hiperparâmetros
N_EPISODES = 10000
ALPHA = 0.1      # Taxa de aprendizado
EPSILON = 0.1    # Exploração
GAMMA = 0.99     # Desconto (já definido no ambiente)

# Treina SARSA
Q_sarsa, rewards_sarsa = sarsa(
    gw,
    n_episodes=N_EPISODES,
    alpha=ALPHA,
    epsilon=EPSILON,
    initial_state=INITIAL_STATE,
    verbose=True
)

print(f"\n✓ Treinamento concluído!")
print(f"Recompensa média últimos 100 episódios: {np.mean(rewards_sarsa[-100:]):.2f}")
# Out:
# ================================================================================
# TREINANDO SARSA
# ================================================================================
# Episódio 100/10000 - Reward médio: -48.76
# Episódio 200/10000 - Reward médio: -29.94
# Episódio 300/10000 - Reward médio: -17.98
# Episódio 400/10000 - Reward médio: -10.04
# Episódio 500/10000 - Reward médio: -9.55
# Episódio 600/10000 - Reward médio: -10.04
# Episódio 700/10000 - Reward médio: -10.46
# Episódio 800/10000 - Reward médio: -10.26
# Episódio 900/10000 - Reward médio: -8.10
# Episódio 1000/10000 - Reward médio: -8.45
# Episódio 1100/10000 - Reward médio: -8.75
# Episódio 1200/10000 - Reward médio: -9.73
# Episódio 1300/10000 - Reward médio: -9.42
# Episódio 1400/10000 - Reward médio: -9.11
# Episódio 1500/10000 - Reward médio: -9.77
# Episódio 1600/10000 - Reward médio: -10.17
# Episódio 1700/10000 - Reward médio: -10.24
# Episódio 1800/10000 - Reward médio: -7.95
# Episódio 1900/10000 - Reward médio: -8.86
# Episódio 2000/10000 - Reward médio: -9.09
# Episódio 2100/10000 - Reward médio: -11.34
# Episódio 2200/10000 - Reward médio: -10.14
# Episódio 2300/10000 - Reward médio: -8.66
# Episódio 2400/10000 - Reward médio: -10.10
# Episódio 2500/10000 - Reward médio: -10.13
# Episódio 2600/10000 - Reward médio: -9.83
# Episódio 2700/10000 - Reward médio: -11.37
# Episódio 2800/10000 - Reward médio: -10.09
# Episódio 2900/10000 - Reward médio: -9.68
# Episódio 3000/10000 - Reward médio: -10.08
# Episódio 3100/10000 - Reward médio: -11.26
# Episódio 3200/10000 - Reward médio: -9.59
# Episódio 3300/10000 - Reward médio: -8.44
# Episódio 3400/10000 - Reward médio: -8.89
# Episódio 3500/10000 - Reward médio: -8.27
# Episódio 3600/10000 - Reward médio: -8.86
# Episódio 3700/10000 - Reward médio: -10.76
# Episódio 3800/10000 - Reward médio: -9.81
# Episódio 3900/10000 - Reward médio: -9.30
# Episódio 4000/10000 - Reward médio: -8.65
# Episódio 4100/10000 - Reward médio: -9.21
# Episódio 4200/10000 - Reward médio: -11.06
# Episódio 4300/10000 - Reward médio: -8.14
# Episódio 4400/10000 - Reward médio: -11.61
# Episódio 4500/10000 - Reward médio: -9.54
# Episódio 4600/10000 - Reward médio: -9.83
# Episódio 4700/10000 - Reward médio: -8.26
# Episódio 4800/10000 - Reward médio: -8.46
# Episódio 4900/10000 - Reward médio: -10.61
# Episódio 5000/10000 - Reward médio: -10.05
# Episódio 5100/10000 - Reward médio: -10.03
# Episódio 5200/10000 - Reward médio: -7.94
# Episódio 5300/10000 - Reward médio: -8.60
# Episódio 5400/10000 - Reward médio: -8.90
# Episódio 5500/10000 - Reward médio: -8.80
# Episódio 5600/10000 - Reward médio: -8.65
# Episódio 5700/10000 - Reward médio: -7.64
# Episódio 5800/10000 - Reward médio: -8.35
# Episódio 5900/10000 - Reward médio: -8.63
# Episódio 6000/10000 - Reward médio: -8.13
# Episódio 6100/10000 - Reward médio: -10.91
# Episódio 6200/10000 - Reward médio: -11.54
# Episódio 6300/10000 - Reward médio: -14.27
# Episódio 6400/10000 - Reward médio: -11.12
# Episódio 6500/10000 - Reward médio: -8.84
# Episódio 6600/10000 - Reward médio: -9.19
# Episódio 6700/10000 - Reward médio: -9.62
# Episódio 6800/10000 - Reward médio: -11.37
# Episódio 6900/10000 - Reward médio: -8.81
# Episódio 7000/10000 - Reward médio: -8.43
# Episódio 7100/10000 - Reward médio: -8.59
# Episódio 7200/10000 - Reward médio: -11.75
# Episódio 7300/10000 - Reward médio: -9.42
# Episódio 7400/10000 - Reward médio: -8.01
# Episódio 7500/10000 - Reward médio: -9.18
# Episódio 7600/10000 - Reward médio: -8.02
# Episódio 7700/10000 - Reward médio: -7.99
# Episódio 7800/10000 - Reward médio: -11.17
# Episódio 7900/10000 - Reward médio: -8.70
# Episódio 8000/10000 - Reward médio: -9.54
# Episódio 8100/10000 - Reward médio: -10.11
# Episódio 8200/10000 - Reward médio: -9.44
# Episódio 8300/10000 - Reward médio: -9.14
# Episódio 8400/10000 - Reward médio: -9.39
# Episódio 8500/10000 - Reward médio: -10.66
# Episódio 8600/10000 - Reward médio: -11.68
# Episódio 8700/10000 - Reward médio: -9.59
# Episódio 8800/10000 - Reward médio: -8.48
# Episódio 8900/10000 - Reward médio: -8.90
# Episódio 9000/10000 - Reward médio: -9.51
# Episódio 9100/10000 - Reward médio: -8.74
# Episódio 9200/10000 - Reward médio: -12.42
# Episódio 9300/10000 - Reward médio: -12.75
# Episódio 9400/10000 - Reward médio: -9.58
# Episódio 9500/10000 - Reward médio: -9.88
# Episódio 9600/10000 - Reward médio: -8.59
# Episódio 9700/10000 - Reward médio: -8.50
# Episódio 9800/10000 - Reward médio: -8.75
# Episódio 9900/10000 - Reward médio: -9.34
# Episódio 10000/10000 - Reward médio: -11.06
#
# ✓ Treinamento concluído!
# Recompensa média últimos 100 episódios: -11.06

# %%
### 2.5 Visualização dos Resultados - SARSA

#### Curva de Aprendizado


plot_learning_curves(
    {'SARSA': rewards_sarsa},
    title="SARSA - Curva de Aprendizado",
    figsize=(14, 5)
)

# %%
#### Política Aprendida


# Extrai política gulosa
policy_sarsa = get_greedy_policy(Q_sarsa, gw)

# Visualiza política
visualize_gridworld(
    gw,
    policy=policy_sarsa,
    title="SARSA - Política Aprendida",
    figsize=(12, 12)
)

# %%
#### Valores Q Aprendidos


# Visualiza valores máximos por estado
visualize_q_values(
    Q_sarsa,
    gw,
    title="SARSA - Valores Q Máximos por Estado",
    figsize=(12, 12)
)

# %% [markdown]
# ## 3. Q-Learning
#
# ### 3.1 Intuição
#
# **Q-Learning** é um algoritmo **off-policy** de TD. Ele aprende o valor $Q(s,a)$ da política **ótima** (gulosa), independentemente da política que está seguindo para exploração.
#
# **Características:**
# - ✅ Aprende a política ótima diretamente
# - ✅ Converge mais rápido
# - ⚠️ Mais agressivo: pode encontrar caminhos arriscados
# - 📊 Ideal quando podemos explorar livremente
#
# ### 3.2 Pseudocódigo
#
# ```
# Inicializar Q(s,a) arbitrariamente
# Para cada episódio:
#     S ← estado inicial
#
#     Repetir para cada passo do episódio:
#         A ← ação escolhida por ε-greedy usando Q
#         Executar ação A, observar R, S'
#
#         Q(S,A) ← Q(S,A) + α[R + γ max_a' Q(S',a') - Q(S,A)]
#
#         S ← S'
#     até S ser terminal
# ```
#
# ### 3.3 Equação de Atualização
#
# $$Q(S_t, A_t) \leftarrow Q(S_t, A_t) + \alpha \left[ R_{t+1} + \gamma \max_{a} Q(S_{t+1}, a) - Q(S_t, A_t) \right]$$
#
# **Diferença chave:** Usa $\max_a Q(S_{t+1}, a)$ (política gulosa) ao invés de $Q(S_{t+1}, A_{t+1})$ (política atual).

# %%
### 3.4 Treinamento do Q-Learning


print("="*80)
print("TREINANDO Q-LEARNING")
print("="*80)

# Treina Q-Learning (mesmos hiperparâmetros)
Q_qlearning, rewards_qlearning = q_learning(
    gw,
    n_episodes=N_EPISODES,
    alpha=ALPHA,
    epsilon=EPSILON,
    initial_state=INITIAL_STATE,
    verbose=True
)

print(f"\n✓ Treinamento concluído!")
print(f"Recompensa média últimos 100 episódios: {np.mean(rewards_qlearning[-100:]):.2f}")
# Out:
# ================================================================================
# TREINANDO Q-LEARNING
# ================================================================================
# Episódio 100/10000 - Reward médio: -53.13
# Episódio 200/10000 - Reward médio: -44.08
# Episódio 300/10000 - Reward médio: -13.27
# Episódio 400/10000 - Reward médio: -8.93
# Episódio 500/10000 - Reward médio: -8.91
# Episódio 600/10000 - Reward médio: -9.11
# Episódio 700/10000 - Reward médio: -10.37
# Episódio 800/10000 - Reward médio: -7.93
# Episódio 900/10000 - Reward médio: -11.24
# Episódio 1000/10000 - Reward médio: -12.11
# Episódio 1100/10000 - Reward médio: -9.40
# Episódio 1200/10000 - Reward médio: -9.61
# Episódio 1300/10000 - Reward médio: -8.83
# Episódio 1400/10000 - Reward médio: -8.94
# Episódio 1500/10000 - Reward médio: -9.62
# Episódio 1600/10000 - Reward médio: -9.82
# Episódio 1700/10000 - Reward médio: -10.38
# Episódio 1800/10000 - Reward médio: -10.36
# Episódio 1900/10000 - Reward médio: -11.11
# Episódio 2000/10000 - Reward médio: -10.77
# Episódio 2100/10000 - Reward médio: -9.63
# Episódio 2200/10000 - Reward médio: -9.39
# Episódio 2300/10000 - Reward médio: -9.01
# Episódio 2400/10000 - Reward médio: -8.38
# Episódio 2500/10000 - Reward médio: -8.83
# Episódio 2600/10000 - Reward médio: -10.04
# Episódio 2700/10000 - Reward médio: -10.71
# Episódio 2800/10000 - Reward médio: -7.19
# Episódio 2900/10000 - Reward médio: -9.45
# Episódio 3000/10000 - Reward médio: -9.38
# Episódio 3100/10000 - Reward médio: -9.98
# Episódio 3200/10000 - Reward médio: -9.22
# Episódio 3300/10000 - Reward médio: -9.90
# Episódio 3400/10000 - Reward médio: -9.65
# Episódio 3500/10000 - Reward médio: -9.36
# Episódio 3600/10000 - Reward médio: -9.31
# Episódio 3700/10000 - Reward médio: -8.74
# Episódio 3800/10000 - Reward médio: -9.58
# Episódio 3900/10000 - Reward médio: -10.70
# Episódio 4000/10000 - Reward médio: -9.52
# Episódio 4100/10000 - Reward médio: -9.90
# Episódio 4200/10000 - Reward médio: -9.47
# Episódio 4300/10000 - Reward médio: -8.48
# Episódio 4400/10000 - Reward médio: -7.25
# Episódio 4500/10000 - Reward médio: -8.71
# Episódio 4600/10000 - Reward médio: -14.61
# Episódio 4700/10000 - Reward médio: -10.11
# Episódio 4800/10000 - Reward médio: -10.34
# Episódio 4900/10000 - Reward médio: -9.91
# Episódio 5000/10000 - Reward médio: -9.04
# Episódio 5100/10000 - Reward médio: -8.48
# Episódio 5200/10000 - Reward médio: -11.14
# Episódio 5300/10000 - Reward médio: -9.01
# Episódio 5400/10000 - Reward médio: -9.69
# Episódio 5500/10000 - Reward médio: -8.50
# Episódio 5600/10000 - Reward médio: -9.49
# Episódio 5700/10000 - Reward médio: -9.43
# Episódio 5800/10000 - Reward médio: -10.44
# Episódio 5900/10000 - Reward médio: -9.38
# Episódio 6000/10000 - Reward médio: -10.96
# Episódio 6100/10000 - Reward médio: -11.66
# Episódio 6200/10000 - Reward médio: -10.76
# Episódio 6300/10000 - Reward médio: -8.48
# Episódio 6400/10000 - Reward médio: -7.64
# Episódio 6500/10000 - Reward médio: -9.16
# Episódio 6600/10000 - Reward médio: -8.80
# Episódio 6700/10000 - Reward médio: -10.85
# Episódio 6800/10000 - Reward médio: -10.55
# Episódio 6900/10000 - Reward médio: -9.48
# Episódio 7000/10000 - Reward médio: -8.40
# Episódio 7100/10000 - Reward médio: -10.64
# Episódio 7200/10000 - Reward médio: -10.02
# Episódio 7300/10000 - Reward médio: -11.60
# Episódio 7400/10000 - Reward médio: -9.86
# Episódio 7500/10000 - Reward médio: -9.86
# Episódio 7600/10000 - Reward médio: -16.36
# Episódio 7700/10000 - Reward médio: -12.33
# Episódio 7800/10000 - Reward médio: -10.19
# Episódio 7900/10000 - Reward médio: -10.14
# Episódio 8000/10000 - Reward médio: -11.04
# Episódio 8100/10000 - Reward médio: -10.87
# Episódio 8200/10000 - Reward médio: -10.51
# Episódio 8300/10000 - Reward médio: -9.20
# Episódio 8400/10000 - Reward médio: -10.48
# Episódio 8500/10000 - Reward médio: -8.86
# Episódio 8600/10000 - Reward médio: -8.83
# Episódio 8700/10000 - Reward médio: -9.55
# Episódio 8800/10000 - Reward médio: -9.32
# Episódio 8900/10000 - Reward médio: -9.39
# Episódio 9000/10000 - Reward médio: -10.71
# Episódio 9100/10000 - Reward médio: -12.34
# Episódio 9200/10000 - Reward médio: -12.18
# Episódio 9300/10000 - Reward médio: -9.01
# Episódio 9400/10000 - Reward médio: -8.94
# Episódio 9500/10000 - Reward médio: -9.54
# Episódio 9600/10000 - Reward médio: -7.78
# Episódio 9700/10000 - Reward médio: -8.57
# Episódio 9800/10000 - Reward médio: -8.77
# Episódio 9900/10000 - Reward médio: -9.30
# Episódio 10000/10000 - Reward médio: -9.50
#
# ✓ Treinamento concluído!
# Recompensa média últimos 100 episódios: -9.50

# %%
### 3.5 Visualização dos Resultados - Q-Learning

#### Curva de Aprendizado


plot_learning_curves(
    {'Q-Learning': rewards_qlearning},
    title="Q-Learning - Curva de Aprendizado",
    figsize=(14, 5)
)

# %%
#### Política Aprendida


# Extrai política gulosa
policy_qlearning = get_greedy_policy(Q_qlearning, gw)

# Visualiza política
visualize_gridworld(
    gw,
    policy=policy_qlearning,
    title="Q-Learning - Política Aprendida",
    figsize=(12, 12)
)

# %%
#### Valores Q Aprendidos


# Visualiza valores máximos por estado
visualize_q_values(
    Q_qlearning,
    gw,
    title="Q-Learning - Valores Q Máximos por Estado",
    figsize=(12, 12)
)

# %% [markdown]
# ## 4. Expected SARSA
#
# ### 4.1 Intuição
#
# **Expected SARSA** é uma variação do SARSA que usa o **valor esperado** das ações no próximo estado ao invés de uma ação específica. Isso reduz a variância das atualizações.
#
# **Características:**
# - ✅ Menos variância que SARSA
# - ✅ Mais estável que Q-Learning
# - ✅ Pode ser on-policy ou off-policy
# - 📊 Bom compromisso entre SARSA e Q-Learning
#
# ### 4.2 Pseudocódigo
#
# ```
# Inicializar Q(s,a) arbitrariamente
# Para cada episódio:
#     S ← estado inicial
#
#     Repetir para cada passo do episódio:
#         A ← ação escolhida por ε-greedy usando Q
#         Executar ação A, observar R, S'
#
#         expected_Q ← Σ_a' π(a'|S') Q(S',a')
#         Q(S,A) ← Q(S,A) + α[R + γ expected_Q - Q(S,A)]
#
#         S ← S'
#     até S ser terminal
# ```
#
# ### 4.3 Equação de Atualização
#
# $$Q(S_t, A_t) \leftarrow Q(S_t, A_t) + \alpha \left[ R_{t+1} + \gamma \mathbb{E}_\pi[Q(S_{t+1}, \cdot)] - Q(S_t, A_t) \right]$$
#
# onde:
#
# $$\mathbb{E}_\pi[Q(S_{t+1}, \cdot)] = \sum_{a} \pi(a|S_{t+1}) Q(S_{t+1}, a)$$
#
# Para política $\epsilon$-greedy:
#
# $$\mathbb{E}_\pi[Q(s, \cdot)] = (1-\epsilon) \max_a Q(s,a) + \epsilon \cdot \frac{1}{|A|} \sum_a Q(s,a)$$

# %%
### 4.4 Treinamento do Expected SARSA


print("="*80)
print("TREINANDO EXPECTED SARSA")
print("="*80)

# Treina Expected SARSA
Q_expected, rewards_expected = expected_sarsa(
    gw,
    n_episodes=N_EPISODES,
    alpha=ALPHA,
    epsilon=EPSILON,
    initial_state=INITIAL_STATE,
    verbose=True
)

print(f"\n✓ Treinamento concluído!")
print(f"Recompensa média últimos 100 episódios: {np.mean(rewards_expected[-100:]):.2f}")
# Out:
# ================================================================================
# TREINANDO EXPECTED SARSA
# ================================================================================
# Episódio 100/10000 - Reward médio: -45.49
# Episódio 200/10000 - Reward médio: -45.08
# Episódio 300/10000 - Reward médio: -23.62
# Episódio 400/10000 - Reward médio: -9.50
# Episódio 500/10000 - Reward médio: -9.13
# Episódio 600/10000 - Reward médio: -9.99
# Episódio 700/10000 - Reward médio: -8.77
# Episódio 800/10000 - Reward médio: -9.02
# Episódio 900/10000 - Reward médio: -8.86
# Episódio 1000/10000 - Reward médio: -10.68
# Episódio 1100/10000 - Reward médio: -9.68
# Episódio 1200/10000 - Reward médio: -10.14
# Episódio 1300/10000 - Reward médio: -8.57
# Episódio 1400/10000 - Reward médio: -10.13
# Episódio 1500/10000 - Reward médio: -9.28
# Episódio 1600/10000 - Reward médio: -8.36
# Episódio 1700/10000 - Reward médio: -9.05
# Episódio 1800/10000 - Reward médio: -9.78
# Episódio 1900/10000 - Reward médio: -9.48
# Episódio 2000/10000 - Reward médio: -11.08
# Episódio 2100/10000 - Reward médio: -8.88
# Episódio 2200/10000 - Reward médio: -11.35
# Episódio 2300/10000 - Reward médio: -8.14
# Episódio 2400/10000 - Reward médio: -10.32
# Episódio 2500/10000 - Reward médio: -9.29
# Episódio 2600/10000 - Reward médio: -9.32
# Episódio 2700/10000 - Reward médio: -8.97
# Episódio 2800/10000 - Reward médio: -8.75
# Episódio 2900/10000 - Reward médio: -8.78
# Episódio 3000/10000 - Reward médio: -9.00
# Episódio 3100/10000 - Reward médio: -9.55
# Episódio 3200/10000 - Reward médio: -9.14
# Episódio 3300/10000 - Reward médio: -9.90
# Episódio 3400/10000 - Reward médio: -9.63
# Episódio 3500/10000 - Reward médio: -9.65
# Episódio 3600/10000 - Reward médio: -8.75
# Episódio 3700/10000 - Reward médio: -9.61
# Episódio 3800/10000 - Reward médio: -11.50
# Episódio 3900/10000 - Reward médio: -10.87
# Episódio 4000/10000 - Reward médio: -10.25
# Episódio 4100/10000 - Reward médio: -9.83
# Episódio 4200/10000 - Reward médio: -10.04
# Episódio 4300/10000 - Reward médio: -8.95
# Episódio 4400/10000 - Reward médio: -8.88
# Episódio 4500/10000 - Reward médio: -10.07
# Episódio 4600/10000 - Reward médio: -8.36
# Episódio 4700/10000 - Reward médio: -9.72
# Episódio 4800/10000 - Reward médio: -10.73
# Episódio 4900/10000 - Reward médio: -9.31
# Episódio 5000/10000 - Reward médio: -10.03
# Episódio 5100/10000 - Reward médio: -8.40
# Episódio 5200/10000 - Reward médio: -8.31
# Episódio 5300/10000 - Reward médio: -7.77
# Episódio 5400/10000 - Reward médio: -10.28
# Episódio 5500/10000 - Reward médio: -9.05
# Episódio 5600/10000 - Reward médio: -10.33
# Episódio 5700/10000 - Reward médio: -9.61
# Episódio 5800/10000 - Reward médio: -11.00
# Episódio 5900/10000 - Reward médio: -9.74
# Episódio 6000/10000 - Reward médio: -9.87
# Episódio 6100/10000 - Reward médio: -9.21
# Episódio 6200/10000 - Reward médio: -8.25
# Episódio 6300/10000 - Reward médio: -8.57
# Episódio 6400/10000 - Reward médio: -9.75
# Episódio 6500/10000 - Reward médio: -9.23
# Episódio 6600/10000 - Reward médio: -8.44
# Episódio 6700/10000 - Reward médio: -9.55
# Episódio 6800/10000 - Reward médio: -9.62
# Episódio 6900/10000 - Reward médio: -10.71
# Episódio 7000/10000 - Reward médio: -8.59
# Episódio 7100/10000 - Reward médio: -8.76
# Episódio 7200/10000 - Reward médio: -9.46
# Episódio 7300/10000 - Reward médio: -11.06
# Episódio 7400/10000 - Reward médio: -9.72
# Episódio 7500/10000 - Reward médio: -9.40
# Episódio 7600/10000 - Reward médio: -9.48
# Episódio 7700/10000 - Reward médio: -9.77
# Episódio 7800/10000 - Reward médio: -10.92
# Episódio 7900/10000 - Reward médio: -10.81
# Episódio 8000/10000 - Reward médio: -8.37
# Episódio 8100/10000 - Reward médio: -9.87
# Episódio 8200/10000 - Reward médio: -9.54
# Episódio 8300/10000 - Reward médio: -9.23
# Episódio 8400/10000 - Reward médio: -8.42
# Episódio 8500/10000 - Reward médio: -8.69
# Episódio 8600/10000 - Reward médio: -10.42
# Episódio 8700/10000 - Reward médio: -8.89
# Episódio 8800/10000 - Reward médio: -10.54
# Episódio 8900/10000 - Reward médio: -9.61
# Episódio 9000/10000 - Reward médio: -8.78
# Episódio 9100/10000 - Reward médio: -9.59
# Episódio 9200/10000 - Reward médio: -10.79
# Episódio 9300/10000 - Reward médio: -10.10
# Episódio 9400/10000 - Reward médio: -9.72
# Episódio 9500/10000 - Reward médio: -10.21
# Episódio 9600/10000 - Reward médio: -8.55
# Episódio 9700/10000 - Reward médio: -9.18
# Episódio 9800/10000 - Reward médio: -11.26
# Episódio 9900/10000 - Reward médio: -9.86
# Episódio 10000/10000 - Reward médio: -9.31
#
# ✓ Treinamento concluído!
# Recompensa média últimos 100 episódios: -9.31

# %%
### 4.5 Visualização dos Resultados - Expected SARSA

#### Curva de Aprendizado


plot_learning_curves(
    {'Expected SARSA': rewards_expected},
    title="Expected SARSA - Curva de Aprendizado",
    figsize=(14, 5)
)

# %%
#### Política Aprendida


# Extrai política gulosa
policy_expected = get_greedy_policy(Q_expected, gw)

# Visualiza política
visualize_gridworld(
    gw,
    policy=policy_expected,
    title="Expected SARSA - Política Aprendida",
    figsize=(12, 12)
)

# %%
#### Valores Q Aprendidos


# Visualiza valores máximos por estado
visualize_q_values(
    Q_expected,
    gw,
    title="Expected SARSA - Valores Q Máximos por Estado",
    figsize=(12, 12)
)

# %% [markdown]
# ---
#
# ## 5. REINFORCE - Monte Carlo Policy Gradient
#
# ### 5.1 Intuição
#
# **REINFORCE** é um algoritmo de **gradiente de política** que parametriza diretamente a política $\pi(a|s, \theta)$ e otimiza os parâmetros $\theta$ para maximizar a recompensa esperada.
#
# **Diferenças fundamentais:**
# - ❌ Não aprende valores Q(s,a)
# - ✅ Aprende política estocástica diretamente
# - ✅ Funciona bem em espaços contínuos
# - ⚠️ Alta variância (usa retornos completos)
#
# **Representação da Política:**
# Usamos política **softmax** (Boltzmann):
#
# $$\pi(a|s, \theta) = \frac{e^{h(s,a,\theta)}}{\sum_{b} e^{h(s,b,\theta)}}$$
#
# onde $h(s,a,\theta) = \theta^T \phi(s,a)$ são as "preferências" e $\phi(s,a)$ são features (one-hot encoding no nosso caso).
#
# ### 5.2 Pseudocódigo
#
# ```
# Inicializar θ (parâmetros da política) arbitrariamente
#
# Para cada episódio:
#     Gerar episódio S₀, A₀, R₁, ..., Sₜ, Aₜ, Rₜ₊₁ seguindo π(·|·,θ)
#
#     Para cada passo t do episódio:
#         Gₜ ← Σₖ₌₀^∞ γᵏ Rₜ₊ₖ₊₁   # Retorno descontado
#
#         θ ← θ + α γᵗ Gₜ ∇log π(Aₜ|Sₜ,θ)
# ```
#
# ### 5.3 Equação de Atualização
#
# **Gradiente do objetivo:**
#
# $$\nabla J(\theta) = \mathbb{E}_\pi \left[ G_t \nabla \log \pi(A_t|S_t, \theta) \right]$$
#
# **Atualização de parâmetros:**
#
# $$\theta \leftarrow \theta + \alpha \gamma^t G_t \nabla \log \pi(A_t|S_t, \theta)$$
#
# **Gradiente para política softmax:**
#
# $$\nabla \log \pi(a|s, \theta) = \phi(s,a) - \sum_{b} \pi(b|s,\theta) \phi(s,b)$$

# %%
### 5.4 Treinamento do REINFORCE


print("="*80)
print("TREINANDO REINFORCE")
print("="*80)

# Hiperparâmetros para REINFORCE
N_EPISODES_PG =10000  # Algoritmos PG geralmente precisam de mais episódios
ALPHA_THETA = 2**-9   # Taxa de aprendizado para parâmetros da política (~0.002)
GAMMA_PG = 0.99

# Treina REINFORCE
theta_reinforce, rewards_reinforce = reinforce(
    gw,
    n_episodes=N_EPISODES_PG,
    alpha_theta=ALPHA_THETA,
    gamma=GAMMA_PG,
    initial_state=INITIAL_STATE,
    verbose=True
)

print(f"\n✓ Treinamento concluído!")
print(f"Recompensa média últimos 100 episódios: {np.mean(rewards_reinforce[-100:]):.2f}")
# Out:
# ================================================================================
# TREINANDO REINFORCE
# ================================================================================
# EpisÃ³dio 100/10000 - Reward mÃ©dio: -16.41
# EpisÃ³dio 200/10000 - Reward mÃ©dio: -13.62
# EpisÃ³dio 300/10000 - Reward mÃ©dio: -11.39
# EpisÃ³dio 400/10000 - Reward mÃ©dio: -10.75
# EpisÃ³dio 500/10000 - Reward mÃ©dio: -11.03
# EpisÃ³dio 600/10000 - Reward mÃ©dio: -10.79
# EpisÃ³dio 700/10000 - Reward mÃ©dio: -10.26
# EpisÃ³dio 800/10000 - Reward mÃ©dio: -11.24
# EpisÃ³dio 900/10000 - Reward mÃ©dio: -11.19
# EpisÃ³dio 1000/10000 - Reward mÃ©dio: -10.33
# EpisÃ³dio 1100/10000 - Reward mÃ©dio: -10.36
# EpisÃ³dio 1200/10000 - Reward mÃ©dio: -10.55
# EpisÃ³dio 1300/10000 - Reward mÃ©dio: -10.56
# EpisÃ³dio 1400/10000 - Reward mÃ©dio: -10.69
# EpisÃ³dio 1500/10000 - Reward mÃ©dio: -10.39
# EpisÃ³dio 1600/10000 - Reward mÃ©dio: -10.25
# EpisÃ³dio 1700/10000 - Reward mÃ©dio: -10.31
# EpisÃ³dio 1800/10000 - Reward mÃ©dio: -10.54
# EpisÃ³dio 1900/10000 - Reward mÃ©dio: -10.24
# EpisÃ³dio 2000/10000 - Reward mÃ©dio: -10.30
# EpisÃ³dio 2100/10000 - Reward mÃ©dio: -10.45
# EpisÃ³dio 2200/10000 - Reward mÃ©dio: -10.31
# EpisÃ³dio 2300/10000 - Reward mÃ©dio: -10.77
# EpisÃ³dio 2400/10000 - Reward mÃ©dio: -10.58
# EpisÃ³dio 2500/10000 - Reward mÃ©dio: -10.40
# EpisÃ³dio 2600/10000 - Reward mÃ©dio: -10.45
# EpisÃ³dio 2700/10000 - Reward mÃ©dio: -10.33
# EpisÃ³dio 2800/10000 - Reward mÃ©dio: -10.39
# EpisÃ³dio 2900/10000 - Reward mÃ©dio: -10.38
# EpisÃ³dio 3000/10000 - Reward mÃ©dio: -10.53
# EpisÃ³dio 3100/10000 - Reward mÃ©dio: -10.30
# EpisÃ³dio 3200/10000 - Reward mÃ©dio: -10.66
# EpisÃ³dio 3300/10000 - Reward mÃ©dio: -10.67
# EpisÃ³dio 3400/10000 - Reward mÃ©dio: -10.35
# EpisÃ³dio 3500/10000 - Reward mÃ©dio: -10.33
# EpisÃ³dio 3600/10000 - Reward mÃ©dio: -10.37
# EpisÃ³dio 3700/10000 - Reward mÃ©dio: -10.61
# EpisÃ³dio 3800/10000 - Reward mÃ©dio: -10.42
# EpisÃ³dio 3900/10000 - Reward mÃ©dio: -10.40
# EpisÃ³dio 4000/10000 - Reward mÃ©dio: -10.45
# EpisÃ³dio 4100/10000 - Reward mÃ©dio: -10.47
# EpisÃ³dio 4200/10000 - Reward mÃ©dio: -10.33
# EpisÃ³dio 4300/10000 - Reward mÃ©dio: -10.27
# EpisÃ³dio 4400/10000 - Reward mÃ©dio: -10.32
# EpisÃ³dio 4500/10000 - Reward mÃ©dio: -10.34
# EpisÃ³dio 4600/10000 - Reward mÃ©dio: -10.90
# EpisÃ³dio 4700/10000 - Reward mÃ©dio: -10.24
# EpisÃ³dio 4800/10000 - Reward mÃ©dio: -10.23
# EpisÃ³dio 4900/10000 - Reward mÃ©dio: -10.23
# EpisÃ³dio 5000/10000 - Reward mÃ©dio: -10.47
# EpisÃ³dio 5100/10000 - Reward mÃ©dio: -10.16
# EpisÃ³dio 5200/10000 - Reward mÃ©dio: -10.56
# EpisÃ³dio 5300/10000 - Reward mÃ©dio: -10.38
# EpisÃ³dio 5400/10000 - Reward mÃ©dio: -10.42
# EpisÃ³dio 5500/10000 - Reward mÃ©dio: -10.48
# EpisÃ³dio 5600/10000 - Reward mÃ©dio: -10.29
# EpisÃ³dio 5700/10000 - Reward mÃ©dio: -10.43
# EpisÃ³dio 5800/10000 - Reward mÃ©dio: -10.32
# EpisÃ³dio 5900/10000 - Reward mÃ©dio: -10.38
# EpisÃ³dio 6000/10000 - Reward mÃ©dio: -10.27
# EpisÃ³dio 6100/10000 - Reward mÃ©dio: -10.47
# EpisÃ³dio 6200/10000 - Reward mÃ©dio: -10.29
# EpisÃ³dio 6300/10000 - Reward mÃ©dio: -10.34
# EpisÃ³dio 6400/10000 - Reward mÃ©dio: -10.22
# EpisÃ³dio 6500/10000 - Reward mÃ©dio: -10.20
# EpisÃ³dio 6600/10000 - Reward mÃ©dio: -10.33
# EpisÃ³dio 6700/10000 - Reward mÃ©dio: -10.34
# EpisÃ³dio 6800/10000 - Reward mÃ©dio: -10.19
# EpisÃ³dio 6900/10000 - Reward mÃ©dio: -10.23
# EpisÃ³dio 7000/10000 - Reward mÃ©dio: -10.66
# EpisÃ³dio 7100/10000 - Reward mÃ©dio: -10.24
# EpisÃ³dio 7200/10000 - Reward mÃ©dio: -10.46
# EpisÃ³dio 7300/10000 - Reward mÃ©dio: -10.31
# EpisÃ³dio 7400/10000 - Reward mÃ©dio: -10.32
# EpisÃ³dio 7500/10000 - Reward mÃ©dio: -10.26
# EpisÃ³dio 7600/10000 - Reward mÃ©dio: -10.42
# EpisÃ³dio 7700/10000 - Reward mÃ©dio: -10.46
# EpisÃ³dio 7800/10000 - Reward mÃ©dio: -10.20
# EpisÃ³dio 7900/10000 - Reward mÃ©dio: -10.30
# EpisÃ³dio 8000/10000 - Reward mÃ©dio: -10.24
# EpisÃ³dio 8100/10000 - Reward mÃ©dio: -10.36
# EpisÃ³dio 8200/10000 - Reward mÃ©dio: -10.58
# EpisÃ³dio 8300/10000 - Reward mÃ©dio: -10.83
# EpisÃ³dio 8400/10000 - Reward mÃ©dio: -10.31
# EpisÃ³dio 8500/10000 - Reward mÃ©dio: -10.18
# EpisÃ³dio 8600/10000 - Reward mÃ©dio: -10.31
# EpisÃ³dio 8700/10000 - Reward mÃ©dio: -10.23
# EpisÃ³dio 8800/10000 - Reward mÃ©dio: -10.29
# EpisÃ³dio 8900/10000 - Reward mÃ©dio: -10.23
# EpisÃ³dio 9000/10000 - Reward mÃ©dio: -10.21
# EpisÃ³dio 9100/10000 - Reward mÃ©dio: -10.20
# EpisÃ³dio 9200/10000 - Reward mÃ©dio: -10.23
# EpisÃ³dio 9300/10000 - Reward mÃ©dio: -10.22
# EpisÃ³dio 9400/10000 - Reward mÃ©dio: -10.38
# EpisÃ³dio 9500/10000 - Reward mÃ©dio: -10.23
# EpisÃ³dio 9600/10000 - Reward mÃ©dio: -10.49
# EpisÃ³dio 9700/10000 - Reward mÃ©dio: -10.33
# EpisÃ³dio 9800/10000 - Reward mÃ©dio: -10.18
# EpisÃ³dio 9900/10000 - Reward mÃ©dio: -10.29
# EpisÃ³dio 10000/10000 - Reward mÃ©dio: -10.44
#
# ✓ Treinamento concluído!
# Recompensa média últimos 100 episódios: -10.44

# %%
### 5.5 Visualização dos Resultados - REINFORCE

#### Curva de Aprendizado


plot_policy_gradient_learning(
    {'REINFORCE': rewards_reinforce},
    title="REINFORCE - Curva de Aprendizado",
    figsize=(14, 5)
)

# %%
#### Política Estocástica Aprendida


# Visualiza política estocástica (probabilidades)
visualize_stochastic_policy(
    theta_reinforce,
    gw,
    title="REINFORCE - Política Estocástica π(a|s,θ)",
    figsize=(15, 15),
    show_probs=True
)

# %%
#### Política Determinística (Ação Mais Provável)


# Visualiza apenas a ação mais provável em cada estado
plot_policy_arrows(
    theta_reinforce,
    gw,
    title="REINFORCE - Política Determinística (argmax)",
    figsize=(12, 12)
)

# %% [markdown]
# ## 6. REINFORCE com Baseline
#
# ### 6.1 Intuição
#
# **REINFORCE com Baseline** é uma melhoria do REINFORCE que **reduz a variância** subtraindo uma baseline $b(s)$ do retorno $G_t$. A baseline mais comum é a **função valor** $V(s)$.
#
# **Vantagens:**
# - ✅ Menor variância → aprendizado mais estável
# - ✅ Convergência mais rápida
# - ✅ Baseline é aprendida simultaneamente
# - 📊 Mesma convergência garantida (baseline não causa viés)
#
# **Intuição da Baseline:**
# - Se $G_t > V(s)$: a ação foi **melhor que o esperado** → aumenta probabilidade
# - Se $G_t < V(s)$: a ação foi **pior que o esperado** → diminui probabilidade
#
# ### 6.2 Pseudocódigo
#
# ```
# Inicializar θ (política) e w (baseline) arbitrariamente
#
# Para cada episódio:
#     Gerar episódio S₀, A₀, R₁, ..., Sₜ, Aₜ, Rₜ₊₁ seguindo π(·|·,θ)
#
#     Para cada passo t do episódio:
#         Gₜ ← Σₖ₌₀^∞ γᵏ Rₜ₊ₖ₊₁
#
#         δₜ ← Gₜ - V(Sₜ, w)    # Advantage (vantagem)
#
#         # Atualiza baseline
#         w ← w + αw δₜ ∇V(Sₜ, w)
#
#         # Atualiza política
#         θ ← θ + αθ γᵗ δₜ ∇log π(Aₜ|Sₜ,θ)
# ```
#
# ### 6.3 Equações de Atualização
#
# **Advantage (vantagem):**
#
# $$\delta_t = G_t - V(S_t, w)$$
#
# **Atualização da baseline:**
#
# $$w \leftarrow w + \alpha_w \delta_t \nabla V(S_t, w)$$
#
# No nosso caso, $V(S_t, w) = w_{s_t}$ (one-hot encoding), então $\nabla V(S_t, w) = \mathbf{e}_{s_t}$.
#
# **Atualização da política:**
#
# $$\theta \leftarrow \theta + \alpha_\theta \gamma^t \delta_t \nabla \log \pi(A_t|S_t, \theta)$$

# %%
### 6.4 Treinamento do REINFORCE com Baseline

print("="*80)
print("TREINANDO REINFORCE COM BASELINE")
print("="*80)

# Hiperparâmetros
ALPHA_THETA_RB = 2**-9  # Taxa para política (~0.002)
ALPHA_W = 2**-6         # Taxa para baseline (~0.016)

# Treina REINFORCE com Baseline
theta_rb, w_rb, rewards_rb = reinforce_baseline(
    gw,
    n_episodes=N_EPISODES_PG,
    alpha_theta=ALPHA_THETA_RB,
    alpha_w=ALPHA_W,
    gamma=GAMMA_PG,
    initial_state=INITIAL_STATE,
    verbose=True
)

print(f"\n✓ Treinamento concluído!")
print(f"Recompensa média últimos 100 episódios: {np.mean(rewards_rb[-100:]):.2f}")
# Out:
# ================================================================================
# TREINANDO REINFORCE COM BASELINE
# ================================================================================
# EpisÃ³dio 100/10000 - Reward mÃ©dio: -16.87
# EpisÃ³dio 200/10000 - Reward mÃ©dio: -12.41
# EpisÃ³dio 300/10000 - Reward mÃ©dio: -11.66
# EpisÃ³dio 400/10000 - Reward mÃ©dio: -11.25
# EpisÃ³dio 500/10000 - Reward mÃ©dio: -11.77
# EpisÃ³dio 600/10000 - Reward mÃ©dio: -10.93
# EpisÃ³dio 700/10000 - Reward mÃ©dio: -10.71
# EpisÃ³dio 800/10000 - Reward mÃ©dio: -10.43
# EpisÃ³dio 900/10000 - Reward mÃ©dio: -10.51
# EpisÃ³dio 1000/10000 - Reward mÃ©dio: -11.71
# EpisÃ³dio 1100/10000 - Reward mÃ©dio: -10.48
# EpisÃ³dio 1200/10000 - Reward mÃ©dio: -10.51
# EpisÃ³dio 1300/10000 - Reward mÃ©dio: -10.56
# EpisÃ³dio 1400/10000 - Reward mÃ©dio: -11.06
# EpisÃ³dio 1500/10000 - Reward mÃ©dio: -11.16
# EpisÃ³dio 1600/10000 - Reward mÃ©dio: -10.25
# EpisÃ³dio 1700/10000 - Reward mÃ©dio: -10.27
# EpisÃ³dio 1800/10000 - Reward mÃ©dio: -10.45
# EpisÃ³dio 1900/10000 - Reward mÃ©dio: -10.54
# EpisÃ³dio 2000/10000 - Reward mÃ©dio: -11.12
# EpisÃ³dio 2100/10000 - Reward mÃ©dio: -10.25
# EpisÃ³dio 2200/10000 - Reward mÃ©dio: -10.29
# EpisÃ³dio 2300/10000 - Reward mÃ©dio: -10.35
# EpisÃ³dio 2400/10000 - Reward mÃ©dio: -10.44
# EpisÃ³dio 2500/10000 - Reward mÃ©dio: -10.55
# EpisÃ³dio 2600/10000 - Reward mÃ©dio: -10.47
# EpisÃ³dio 2700/10000 - Reward mÃ©dio: -10.23
# EpisÃ³dio 2800/10000 - Reward mÃ©dio: -10.75
# EpisÃ³dio 2900/10000 - Reward mÃ©dio: -10.74
# EpisÃ³dio 3000/10000 - Reward mÃ©dio: -10.48
# EpisÃ³dio 3100/10000 - Reward mÃ©dio: -10.42
# EpisÃ³dio 3200/10000 - Reward mÃ©dio: -10.47
# EpisÃ³dio 3300/10000 - Reward mÃ©dio: -10.24
# EpisÃ³dio 3400/10000 - Reward mÃ©dio: -10.50
# EpisÃ³dio 3500/10000 - Reward mÃ©dio: -10.23
# EpisÃ³dio 3600/10000 - Reward mÃ©dio: -10.23
# EpisÃ³dio 3700/10000 - Reward mÃ©dio: -10.25
# EpisÃ³dio 3800/10000 - Reward mÃ©dio: -10.29
# EpisÃ³dio 3900/10000 - Reward mÃ©dio: -10.38
# EpisÃ³dio 4000/10000 - Reward mÃ©dio: -10.30
# EpisÃ³dio 4100/10000 - Reward mÃ©dio: -10.31
# EpisÃ³dio 4200/10000 - Reward mÃ©dio: -10.59
# EpisÃ³dio 4300/10000 - Reward mÃ©dio: -10.29
# EpisÃ³dio 4400/10000 - Reward mÃ©dio: -10.23
# EpisÃ³dio 4500/10000 - Reward mÃ©dio: -10.42
# EpisÃ³dio 4600/10000 - Reward mÃ©dio: -10.48
# EpisÃ³dio 4700/10000 - Reward mÃ©dio: -10.47
# EpisÃ³dio 4800/10000 - Reward mÃ©dio: -10.35
# EpisÃ³dio 4900/10000 - Reward mÃ©dio: -10.28
# EpisÃ³dio 5000/10000 - Reward mÃ©dio: -10.18
# EpisÃ³dio 5100/10000 - Reward mÃ©dio: -10.32
# EpisÃ³dio 5200/10000 - Reward mÃ©dio: -10.12
# EpisÃ³dio 5300/10000 - Reward mÃ©dio: -10.08
# EpisÃ³dio 5400/10000 - Reward mÃ©dio: -10.09
# EpisÃ³dio 5500/10000 - Reward mÃ©dio: -10.53
# EpisÃ³dio 5600/10000 - Reward mÃ©dio: -10.20
# EpisÃ³dio 5700/10000 - Reward mÃ©dio: -10.27
# EpisÃ³dio 5800/10000 - Reward mÃ©dio: -10.10
# EpisÃ³dio 5900/10000 - Reward mÃ©dio: -10.15
# EpisÃ³dio 6000/10000 - Reward mÃ©dio: -10.40
# EpisÃ³dio 6100/10000 - Reward mÃ©dio: -10.29
# EpisÃ³dio 6200/10000 - Reward mÃ©dio: -10.28
# EpisÃ³dio 6300/10000 - Reward mÃ©dio: -10.20
# EpisÃ³dio 6400/10000 - Reward mÃ©dio: -10.35
# EpisÃ³dio 6500/10000 - Reward mÃ©dio: -10.19
# EpisÃ³dio 6600/10000 - Reward mÃ©dio: -10.08
# EpisÃ³dio 6700/10000 - Reward mÃ©dio: -10.80
# EpisÃ³dio 6800/10000 - Reward mÃ©dio: -10.28
# EpisÃ³dio 6900/10000 - Reward mÃ©dio: -10.29
# EpisÃ³dio 7000/10000 - Reward mÃ©dio: -10.24
# EpisÃ³dio 7100/10000 - Reward mÃ©dio: -10.40
# EpisÃ³dio 7200/10000 - Reward mÃ©dio: -10.26
# EpisÃ³dio 7300/10000 - Reward mÃ©dio: -10.21
# EpisÃ³dio 7400/10000 - Reward mÃ©dio: -10.29
# EpisÃ³dio 7500/10000 - Reward mÃ©dio: -10.20
# EpisÃ³dio 7600/10000 - Reward mÃ©dio: -10.21
# EpisÃ³dio 7700/10000 - Reward mÃ©dio: -10.22
# EpisÃ³dio 7800/10000 - Reward mÃ©dio: -10.23
# EpisÃ³dio 7900/10000 - Reward mÃ©dio: -10.19
# EpisÃ³dio 8000/10000 - Reward mÃ©dio: -10.25
# EpisÃ³dio 8100/10000 - Reward mÃ©dio: -10.23
# EpisÃ³dio 8200/10000 - Reward mÃ©dio: -10.19
# EpisÃ³dio 8300/10000 - Reward mÃ©dio: -10.38
# EpisÃ³dio 8400/10000 - Reward mÃ©dio: -10.35
# EpisÃ³dio 8500/10000 - Reward mÃ©dio: -10.25
# EpisÃ³dio 8600/10000 - Reward mÃ©dio: -10.29
# EpisÃ³dio 8700/10000 - Reward mÃ©dio: -10.17
# EpisÃ³dio 8800/10000 - Reward mÃ©dio: -10.06
# EpisÃ³dio 8900/10000 - Reward mÃ©dio: -10.38
# EpisÃ³dio 9000/10000 - Reward mÃ©dio: -10.22
# EpisÃ³dio 9100/10000 - Reward mÃ©dio: -10.11
# EpisÃ³dio 9200/10000 - Reward mÃ©dio: -10.31
# EpisÃ³dio 9300/10000 - Reward mÃ©dio: -10.19
# EpisÃ³dio 9400/10000 - Reward mÃ©dio: -10.27
# EpisÃ³dio 9500/10000 - Reward mÃ©dio: -10.16
# EpisÃ³dio 9600/10000 - Reward mÃ©dio: -10.39
# EpisÃ³dio 9700/10000 - Reward mÃ©dio: -10.16
# EpisÃ³dio 9800/10000 - Reward mÃ©dio: -10.45
# EpisÃ³dio 9900/10000 - Reward mÃ©dio: -10.35
# EpisÃ³dio 10000/10000 - Reward mÃ©dio: -10.16
#
# ✓ Treinamento concluído!
# Recompensa média últimos 100 episódios: -10.16

# %%
### 6.5 Visualização dos Resultados - REINFORCE Baseline

#### Curva de Aprendizado


plot_policy_gradient_learning(
    {'REINFORCE + Baseline': rewards_rb},
    title="REINFORCE com Baseline - Curva de Aprendizado",
    figsize=(14, 5)
)

# %%
#### Política Estocástica Aprendida


# Visualiza política estocástica
visualize_stochastic_policy(
    theta_rb,
    gw,
    title="REINFORCE + Baseline - Política Estocástica π(a|s,θ)",
    figsize=(15, 15),
    show_probs=True
)

# %%
#### Política Determinística


# Visualiza ação mais provável
plot_policy_arrows(
    theta_rb,
    gw,
    title="REINFORCE + Baseline - Política Determinística (argmax)",
    figsize=(12, 12)
)

# %% [markdown]
# ## 7. Actor-Critic (One-Step)
#
# ### 7.1 Intuição
#
# **Actor-Critic** combina o melhor de dois mundos:
# - **Actor (Ator)**: Aprende a política $\pi(a|s, \theta)$ (como REINFORCE)
# - **Critic (Crítico)**: Aprende a função valor $V(s, w)$ (como TD)
#
# **Vantagens sobre REINFORCE:**
# - ✅ Atualização **online** (a cada passo, não no fim do episódio)
# - ✅ **Bootstrapping**: usa $V(s')$ ao invés de $G_t$ → menor variância
# - ✅ Mais eficiente em termos de dados
# - 📊 Baseline aprendida pelo critic automaticamente
#
# **Componentes:**
# 1. **Actor**: Política $\pi(a|s, \theta)$ que escolhe ações
# 2. **Critic**: Função valor $V(s, w)$ que avalia estados
# 3. **TD Error**: $\delta = R + \gamma V(s') - V(s)$ guia ambos
#
# ### 7.2 Pseudocódigo
#
# ```
# Inicializar θ (actor) e w (critic) arbitrariamente
#
# Para cada episódio:
#     S ← estado inicial
#     I ← 1  # Fator de desconto acumulado
#
#     Enquanto S não é terminal:
#         A ~ π(·|S,θ)              # Actor escolhe ação
#         Executar A, observar R, S'
#
#         # Calcula TD error
#         δ ← R + γ V(S',w) - V(S,w)
#
#         # Atualiza Critic
#         w ← w + αw δ ∇V(S,w)
#
#         # Atualiza Actor
#         θ ← θ + αθ I δ ∇log π(A|S,θ)
#
#         I ← γI
#         S ← S'
# ```
#
# ### 7.3 Equações de Atualização
#
# **TD Error (sinal de ensino):**
#
# $$\delta_t = R_{t+1} + \gamma V(S_{t+1}, w) - V(S_t, w)$$
#
# **Atualização do Critic:**
#
# $$w \leftarrow w + \alpha_w \delta_t \nabla V(S_t, w)$$
#
# **Atualização do Actor:**
#
# $$\theta \leftarrow \theta + \alpha_\theta I_t \delta_t \nabla \log \pi(A_t|S_t, \theta)$$
#
# onde $I_t = \gamma^t$ é o fator de desconto acumulado.

# %%
### 7.4 Treinamento do Actor-Critic

print("="*80)
print("TREINANDO ACTOR-CRITIC")
print("="*80)

# Hiperparâmetros
ALPHA_THETA_AC = 0.05  # Taxa para actor
ALPHA_W_AC = 0.015     # Taxa para critic

# Treina Actor-Critic
theta_ac, w_ac, rewards_ac = actor_critic(
    gw,
    n_episodes=N_EPISODES_PG,
    alpha_theta=ALPHA_THETA_AC,
    alpha_w=ALPHA_W_AC,
    gamma=GAMMA_PG,
    initial_state=INITIAL_STATE,
    verbose=True
)

print(f"\n✓ Treinamento concluído!")
print(f"Recompensa média últimos 100 episódios: {np.mean(rewards_ac[-100:]):.2f}")
# Out:
# ================================================================================
# TREINANDO ACTOR-CRITIC
# ================================================================================
# EpisÃ³dio 100/10000 - Reward mÃ©dio: -47.97
# EpisÃ³dio 200/10000 - Reward mÃ©dio: -58.47
# EpisÃ³dio 300/10000 - Reward mÃ©dio: -15.14
# EpisÃ³dio 400/10000 - Reward mÃ©dio: -12.29
# EpisÃ³dio 500/10000 - Reward mÃ©dio: -10.22
# EpisÃ³dio 600/10000 - Reward mÃ©dio: -8.38
# EpisÃ³dio 700/10000 - Reward mÃ©dio: -8.56
# EpisÃ³dio 800/10000 - Reward mÃ©dio: -7.44
# EpisÃ³dio 900/10000 - Reward mÃ©dio: -9.57
# EpisÃ³dio 1000/10000 - Reward mÃ©dio: -6.82
# EpisÃ³dio 1100/10000 - Reward mÃ©dio: -7.36
# EpisÃ³dio 1200/10000 - Reward mÃ©dio: -7.73
# EpisÃ³dio 1300/10000 - Reward mÃ©dio: -7.50
# EpisÃ³dio 1400/10000 - Reward mÃ©dio: -7.71
# EpisÃ³dio 1500/10000 - Reward mÃ©dio: -7.31
# EpisÃ³dio 1600/10000 - Reward mÃ©dio: -5.84
# EpisÃ³dio 1700/10000 - Reward mÃ©dio: -7.41
# EpisÃ³dio 1800/10000 - Reward mÃ©dio: -6.50
# EpisÃ³dio 1900/10000 - Reward mÃ©dio: -7.90
# EpisÃ³dio 2000/10000 - Reward mÃ©dio: -8.03
# EpisÃ³dio 2100/10000 - Reward mÃ©dio: -6.22
# EpisÃ³dio 2200/10000 - Reward mÃ©dio: -7.64
# EpisÃ³dio 2300/10000 - Reward mÃ©dio: -6.29
# EpisÃ³dio 2400/10000 - Reward mÃ©dio: -6.62
# EpisÃ³dio 2500/10000 - Reward mÃ©dio: -7.93
# EpisÃ³dio 2600/10000 - Reward mÃ©dio: -6.02
# EpisÃ³dio 2700/10000 - Reward mÃ©dio: -5.87
# EpisÃ³dio 2800/10000 - Reward mÃ©dio: -5.68
# EpisÃ³dio 2900/10000 - Reward mÃ©dio: -6.80
# EpisÃ³dio 3000/10000 - Reward mÃ©dio: -6.72
# EpisÃ³dio 3100/10000 - Reward mÃ©dio: -8.15
# EpisÃ³dio 3200/10000 - Reward mÃ©dio: -6.47
# EpisÃ³dio 3300/10000 - Reward mÃ©dio: -6.58
# EpisÃ³dio 3400/10000 - Reward mÃ©dio: -6.36
# EpisÃ³dio 3500/10000 - Reward mÃ©dio: -6.10
# EpisÃ³dio 3600/10000 - Reward mÃ©dio: -6.74
# EpisÃ³dio 3700/10000 - Reward mÃ©dio: -6.48
# EpisÃ³dio 3800/10000 - Reward mÃ©dio: -5.55
# EpisÃ³dio 3900/10000 - Reward mÃ©dio: -7.06
# EpisÃ³dio 4000/10000 - Reward mÃ©dio: -7.01
# EpisÃ³dio 4100/10000 - Reward mÃ©dio: -6.14
# EpisÃ³dio 4200/10000 - Reward mÃ©dio: -7.53
# EpisÃ³dio 4300/10000 - Reward mÃ©dio: -5.14
# EpisÃ³dio 4400/10000 - Reward mÃ©dio: -7.24
# EpisÃ³dio 4500/10000 - Reward mÃ©dio: -6.40
# EpisÃ³dio 4600/10000 - Reward mÃ©dio: -6.59
# EpisÃ³dio 4700/10000 - Reward mÃ©dio: -6.70
# EpisÃ³dio 4800/10000 - Reward mÃ©dio: -7.20
# EpisÃ³dio 4900/10000 - Reward mÃ©dio: -6.93
# EpisÃ³dio 5000/10000 - Reward mÃ©dio: -5.62
# EpisÃ³dio 5100/10000 - Reward mÃ©dio: -5.75
# EpisÃ³dio 5200/10000 - Reward mÃ©dio: -6.38
# EpisÃ³dio 5300/10000 - Reward mÃ©dio: -6.64
# EpisÃ³dio 5400/10000 - Reward mÃ©dio: -6.53
# EpisÃ³dio 5500/10000 - Reward mÃ©dio: -7.57
# EpisÃ³dio 5600/10000 - Reward mÃ©dio: -5.60
# EpisÃ³dio 5700/10000 - Reward mÃ©dio: -8.11
# EpisÃ³dio 5800/10000 - Reward mÃ©dio: -7.16
# EpisÃ³dio 5900/10000 - Reward mÃ©dio: -7.45
# EpisÃ³dio 6000/10000 - Reward mÃ©dio: -5.77
# EpisÃ³dio 6100/10000 - Reward mÃ©dio: -6.71
# EpisÃ³dio 6200/10000 - Reward mÃ©dio: -7.01
# EpisÃ³dio 6300/10000 - Reward mÃ©dio: -6.75
# EpisÃ³dio 6400/10000 - Reward mÃ©dio: -7.60
# EpisÃ³dio 6500/10000 - Reward mÃ©dio: -7.05
# EpisÃ³dio 6600/10000 - Reward mÃ©dio: -6.43
# EpisÃ³dio 6700/10000 - Reward mÃ©dio: -5.70
# EpisÃ³dio 6800/10000 - Reward mÃ©dio: -5.87
# EpisÃ³dio 6900/10000 - Reward mÃ©dio: -5.83
# EpisÃ³dio 7000/10000 - Reward mÃ©dio: -6.94
# EpisÃ³dio 7100/10000 - Reward mÃ©dio: -6.26
# EpisÃ³dio 7200/10000 - Reward mÃ©dio: -7.29
# EpisÃ³dio 7300/10000 - Reward mÃ©dio: -6.98
# EpisÃ³dio 7400/10000 - Reward mÃ©dio: -7.78
# EpisÃ³dio 7500/10000 - Reward mÃ©dio: -6.85
# EpisÃ³dio 7600/10000 - Reward mÃ©dio: -7.13
# EpisÃ³dio 7700/10000 - Reward mÃ©dio: -6.63
# EpisÃ³dio 7800/10000 - Reward mÃ©dio: -6.82
# EpisÃ³dio 7900/10000 - Reward mÃ©dio: -6.41
# EpisÃ³dio 8000/10000 - Reward mÃ©dio: -7.18
# EpisÃ³dio 8100/10000 - Reward mÃ©dio: -4.88
# EpisÃ³dio 8200/10000 - Reward mÃ©dio: -6.62
# EpisÃ³dio 8300/10000 - Reward mÃ©dio: -6.32
# EpisÃ³dio 8400/10000 - Reward mÃ©dio: -6.26
# EpisÃ³dio 8500/10000 - Reward mÃ©dio: -6.41
# EpisÃ³dio 8600/10000 - Reward mÃ©dio: -5.82
# EpisÃ³dio 8700/10000 - Reward mÃ©dio: -4.75
# EpisÃ³dio 8800/10000 - Reward mÃ©dio: -6.58
# EpisÃ³dio 8900/10000 - Reward mÃ©dio: -7.14
# EpisÃ³dio 9000/10000 - Reward mÃ©dio: -7.34
# EpisÃ³dio 9100/10000 - Reward mÃ©dio: -5.52
# EpisÃ³dio 9200/10000 - Reward mÃ©dio: -6.97
# EpisÃ³dio 9300/10000 - Reward mÃ©dio: -5.70
# EpisÃ³dio 9400/10000 - Reward mÃ©dio: -6.52
# EpisÃ³dio 9500/10000 - Reward mÃ©dio: -6.04
# EpisÃ³dio 9600/10000 - Reward mÃ©dio: -6.99
# EpisÃ³dio 9700/10000 - Reward mÃ©dio: -5.64
# EpisÃ³dio 9800/10000 - Reward mÃ©dio: -7.32
# EpisÃ³dio 9900/10000 - Reward mÃ©dio: -7.02
# EpisÃ³dio 10000/10000 - Reward mÃ©dio: -6.96
#
# ✓ Treinamento concluído!
# Recompensa média últimos 100 episódios: -6.96

# %%
### 7.5 Visualização dos Resultados - Actor-Critic

#### Curva de Aprendizado


plot_policy_gradient_learning(
    {'Actor-Critic': rewards_ac},
    title="Actor-Critic - Curva de Aprendizado",
    figsize=(14, 5)
)

# %%
#### Política Estocástica Aprendida


# Visualiza política estocástica
visualize_stochastic_policy(
    theta_ac,
    gw,
    title="Actor-Critic - Política Estocástica π(a|s,θ)",
    figsize=(15, 15),
    show_probs=True
)

# %%
#### Política Determinística


# Visualiza ação mais provável
plot_policy_arrows(
    theta_ac,
    gw,
    title="Actor-Critic - Política Determinística (argmax)",
    figsize=(12, 12)
)

# %%
#### Função Valor e Política Juntas


# Visualização especial: Critic (valores) e Actor (política) lado a lado
plot_value_and_policy(
    w_ac,
    theta_ac,
    gw,
    title="Actor-Critic - Função Valor V(s,w) e Política π(a|s,θ)",
    figsize=(20, 10)
)

# %%
## 8. Comparação Final

### 8.1 Comparação das Curvas de Aprendizado

#### Algoritmos Baseados em Valor (TD)


# Compara SARSA, Q-Learning e Expected SARSA
plot_learning_curves(
    {
        'SARSA': rewards_sarsa,
        'Q-Learning': rewards_qlearning,
        'Expected SARSA': rewards_expected
    },
    title="Comparação: Algoritmos TD (Baseados em Valor)",
    figsize=(16, 6)
)

# %%
#### Algoritmos de Gradiente de Política


# Compara REINFORCE, REINFORCE+Baseline e Actor-Critic
plot_policy_gradient_learning(
    {
        'REINFORCE': rewards_reinforce,
        'REINFORCE + Baseline': rewards_rb,
        'Actor-Critic': rewards_ac
    },
    title="Comparação: Algoritmos de Gradiente de Política",
    figsize=(16, 6)
)

# %%
#### Todos os Algoritmos Juntos


# Comparação completa
plot_learning_curves(
    {
        'SARSA': rewards_sarsa,
        'Q-Learning': rewards_qlearning,
        'Expected SARSA': rewards_expected,
        'REINFORCE': rewards_reinforce,
        'REINFORCE + Baseline': rewards_rb,
        'Actor-Critic': rewards_ac
    },
    title="Comparação: Todos os Algoritmos",
    figsize=(18, 6)
)

# %%
### 8.2 Comparação dos Valores Aprendidos (TD)


# Compara valores Q aprendidos pelos algoritmos TD
compare_algorithms(
    {
        'SARSA': Q_sarsa,
        'Q-Learning': Q_qlearning,
        'Expected SARSA': Q_expected
    },
    gw
)
# Out:
# ================================================================================
# COMPARAÇÃO DE VALORES APRENDIDOS
# ================================================================================
#
# Estado         SARSA               Q-Learning          Expected SARSA
# --------------------------------------------------------------------------------
# (0, 0)         -9.0324             -8.8707             -10.7245
# (1, 0)         -7.9504             -7.6431             -7.6371
# (1, 1)         -7.9983             -7.7549             -7.6460
# (1, 2)         -6.7098             -4.0637             -9.0667
# (1, 3)         -4.9550             -0.1900             -8.8046
# (1, 4)         -0.1000             -0.1106             -3.5400
# (1, 5)         0.0000              0.0000              -0.1903
# (1, 6)         0.0000              0.0000              -0.1113
# (1, 7)         0.0000              0.0000              0.0000
# (1, 8)         0.0000              0.0000              0.0000
# (1, 9)         1.0000              2.5480              2.7100
# (2, 0)         -7.7161             -7.2912             -7.5900
# (2, 1)         -8.0278             -7.6809             -7.7460
# (2, 3)         -5.0791             -0.1000             -9.0729
# (2, 5)         0.0000              0.0000              -0.3094
# (2, 7)         0.0000              0.0000              0.0000
# (2, 9)         2.8569              5.5242              1.9479
# (3, 0)         -7.2504             -6.0041             -7.4354
# (3, 2)         -6.9104             -4.4376             -6.5582
# (3, 4)         -3.8727             -2.2730             -4.6429
# (3, 6)         -1.2268             0.6024              -2.7843
# (3, 8)         5.3816              5.5488              4.4725
# (3, 9)         7.3083              7.5981              7.3474
# (4, 0)         -7.2367             -5.5625             -7.0839
# (4, 1)         -6.6828             -4.5636             -6.5261
# (4, 2)         -5.5947             -3.1201             -5.9676
# (4, 3)         -4.8464             -2.0778             -5.7116
# (4, 4)         -3.0119             -2.4095             -4.0298
# (4, 5)         -0.9410             -1.6504             -2.4517
# (4, 6)         -0.4527             0.7339              -0.6194
# (4, 7)         1.4934              4.8835              1.3304
# (4, 8)         6.9807              7.5444              3.0169
# (4, 9)         9.9468              9.9350              9.1148
# (5, 0)         -7.7703             -6.2850             -7.6235
# ================================================================================
#
# ESTATÍSTICAS RESUMIDAS:
# --------------------------------------------------------------------------------
#
# SARSA:
#   Valor médio:   -2.3058
#   Valor máximo:  9.9468
#   Valor mínimo:  -9.0324
#   Desvio padrão: 4.9348
#
# Q-Learning:
#   Valor médio:   -1.0932
#   Valor máximo:  9.9350
#   Valor mínimo:  -8.8707
#   Desvio padrão: 4.7465
#
# Expected SARSA:
#   Valor médio:   -3.0569
#   Valor máximo:  9.1148
#   Valor mínimo:  -10.7245
#   Desvio padrão: 4.9553

# %%
### 8.3 Estatísticas Resumidas


print("\n" + "="*80)
print("ESTATÍSTICAS RESUMIDAS - TODOS OS ALGORITMOS")
print("="*80)

algorithms_results = {
    'SARSA': rewards_sarsa,
    'Q-Learning': rewards_qlearning,
    'Expected SARSA': rewards_expected,
    'REINFORCE': rewards_reinforce,
    'REINFORCE + Baseline': rewards_rb,
    'Actor-Critic': rewards_ac
}

print(f"\n{'Algoritmo':<25} {'Média Final':<15} {'Std Final':<15} {'Melhor':<15}")
print("-"*80)

for name, rewards in algorithms_results.items():
    final_mean = np.mean(rewards[-100:])
    final_std = np.std(rewards[-100:])
    best = np.max(rewards)
    print(f"{name:<25} {final_mean:<15.2f} {final_std:<15.2f} {best:<15.2f}")

print("="*80)
# Out:
# ================================================================================
# ESTATÍSTICAS RESUMIDAS - TODOS OS ALGORITMOS
# ================================================================================
#
# Algoritmo                 Média Final     Std Final       Melhor
# --------------------------------------------------------------------------------
# SARSA                     -11.06          8.26            0.00
# Q-Learning                -9.50           6.90            0.00
# Expected SARSA            -9.31           5.80            0.00
# REINFORCE                 -10.20          0.63            -10.00
# REINFORCE + Baseline      -10.16          0.50            -10.00
# Actor-Critic              -6.96           7.32            0.00
# ================================================================================

# %% [markdown]
# ### 8.4 Análise Comparativa
#
#
# ### ANÁLISE COMPARATIVA
#
#
# 🔍 ALGORITMOS TD (Baseados em Valor):
# ---
#
# ✓ SARSA (On-Policy):
#   • Aprende a política que está seguindo (incluindo ε-exploration)
#   • Mais conservador e seguro
#   • Evita caminhos muito próximos ao abismo
#   • Convergência estável
#
# ✓ Q-Learning (Off-Policy):
#   • Aprende a política ótima diretamente
#   • Mais agressivo, pode encontrar caminhos arriscados
#   • Convergência mais rápida
#   • Pode escolher caminhos próximos ao abismo (ótimos mas arriscados)
#
# ✓ Expected SARSA:
#   • Reduz variância usando valor esperado
#   • Compromisso entre SARSA e Q-Learning
#   • Convergência suave e estável
#
#
# 🎭 ALGORITMOS DE GRADIENTE DE POLÍTICA:
# ---
#
# ✓ REINFORCE:
#   • Aprende política estocástica diretamente
#   • Alta variância (usa retornos completos Gt)
#   • Atualizações apenas no fim do episódio
#   • Requer muitos episódios para convergir
#
# ✓ REINFORCE + Baseline:
#   • Reduz variância usando baseline V(s)
#   • Convergência mais rápida que REINFORCE puro
#   • Ainda episódico (atualiza no fim)
#   • Aprende baseline automaticamente
#
# ✓ Actor-Critic:
#   • Atualização ONLINE (a cada passo)
#   • Bootstrapping reduz variância
#   • Mais eficiente em dados
#   • Combina vantagens de TD e Policy Gradient
#
#
# 🏆 COMPARAÇÃO GERAL:
# ---
#
# ### Velocidade de Convergência:
#   1. Q-Learning (mais rápido)
#   2. Expected SARSA
#   3. SARSA
#   4. Actor-Critic
#   5. REINFORCE + Baseline
#   6. REINFORCE (mais lento)
#
# ### Estabilidade:
#   1. Expected SARSA (mais estável)
#   2. Actor-Critic
#   3. SARSA
#   4. REINFORCE + Baseline
#   5. Q-Learning
#   6. REINFORCE (mais instável)
#
# ### Eficiência em Dados:
#   • TD methods > Policy Gradient methods
#   • Actor-Critic > REINFORCE variants
#
# ### Aplicabilidade:
#   • TD methods: Excelentes para espaços discretos
#   • Policy Gradient: Escaláveis para contínuos/alta dimensão

# %%
### 8.5 Visualização Final - Grade Comparativa de Políticas

# Cria visualização comparativa das políticas aprendidas
fig, axes = plt.subplots(2, 3, figsize=(24, 16))

# Políticas TD
for idx, (name, Q, ax) in enumerate([
    ('SARSA', Q_sarsa, axes[0, 0]),
    ('Q-Learning', Q_qlearning, axes[0, 1]),
    ('Expected SARSA', Q_expected, axes[0, 2])
]):
    policy = get_greedy_policy(Q, gw)
    
    ax.set_xlim(-0.5, gw.cols - 0.5)
    ax.set_ylim(gw.rows - 0.5, -0.5)
    ax.set_aspect('equal')
    ax.set_title(f'{name} - Política', fontsize=14, fontweight='bold')
    ax.grid(True, alpha=0.3)
    
    action_symbols = {'N': '↑', 'S': '↓', 'L': '→', 'O': '←'}
    
    for row in range(gw.rows):
        for col in range(gw.cols):
            state = (row, col)
            
            if state in gw.walls:
                ax.add_patch(plt.Rectangle((col-0.4, row-0.4), 0.8, 0.8, 
                                          facecolor='gray', alpha=0.8))
            elif state in gw.terminal_states:
                reward = gw.terminal_states[state]
                color = 'lightgreen' if reward > 0 else 'lightcoral'
                ax.add_patch(plt.Rectangle((col-0.4, row-0.4), 0.8, 0.8,
                                          facecolor=color, alpha=0.6))
                ax.text(col, row, f'{reward:+.0f}', ha='center', va='center',
                       fontsize=12, fontweight='bold')
            elif state in policy:
                action = policy[state]
                symbol = action_symbols[action]
                ax.text(col, row, symbol, ha='center', va='center',
                       fontsize=20, fontweight='bold', color='blue')
# Políticas PG (mostrar ação mais provável)
from algorithms_extended import compute_softmax_policy

for idx, (name, theta, ax) in enumerate([
    ('REINFORCE', theta_reinforce, axes[1, 0]),
    ('REINFORCE + Baseline', theta_rb, axes[1, 1]),
    ('Actor-Critic', theta_ac, axes[1, 2])
]):
    ax.set_xlim(-0.5, gw.cols - 0.5)
    ax.set_ylim(gw.rows - 0.5, -0.5)
    ax.set_aspect('equal')
    ax.set_title(f'{name} - Política', fontsize=14, fontweight='bold')
    ax.grid(True, alpha=0.3)
    
    action_symbols = {'N': '↑', 'S': '↓', 'L': '→', 'O': '←'}
    
    for row in range(gw.rows):
        for col in range(gw.cols):
            state = (row, col)
            
            if state in gw.walls:
                ax.add_patch(plt.Rectangle((col-0.4, row-0.4), 0.8, 0.8,
                                          facecolor='gray', alpha=0.8))
            elif state in gw.terminal_states:
                reward = gw.terminal_states[state]
                color = 'lightgreen' if reward > 0 else 'lightcoral'
                ax.add_patch(plt.Rectangle((col-0.4, row-0.4), 0.8, 0.8,
                                          facecolor=color, alpha=0.6))
                ax.text(col, row, f'{reward:+.0f}', ha='center', va='center',
                       fontsize=12, fontweight='bold')
            else:
                probs = compute_softmax_policy(state, theta, gw)
                best_action_idx = np.argmax(probs)
                best_action = gw.actions[best_action_idx]
                symbol = action_symbols[best_action]
                ax.text(col, row, symbol, ha='center', va='center',
                       fontsize=20, fontweight='bold', color='darkgreen')

plt.suptitle('Comparação de Políticas Aprendidas - Todos os Algoritmos',
             fontsize=16, fontweight='bold', y=0.995)
plt.tight_layout()
plt.show()

# %% [markdown]
# ## 📊 Conclusões
#
# ### Principais Aprendizados:
#
# 1. **Algoritmos TD** convergem mais rápido e são mais eficientes em dados para ambientes discretos
# 2. **Q-Learning** encontra políticas mais agressivas (próximas ao abismo)
# 3. **SARSA** aprende políticas mais conservadoras (caminho seguro)
# 4. **Expected SARSA** oferece o melhor equilíbrio entre velocidade e estabilidade
#
# 5. **REINFORCE** tem alta variância mas funciona bem com ajuste de hiperparâmetros
# 6. **Baseline** reduz significativamente a variância do REINFORCE
# 7. **Actor-Critic** combina vantagens de TD e PG, sendo o mais versátil
#
# ### Quando usar cada algoritmo?
#
# **SARSA**:
# - Quando a exploração tem custo real
# - Ambientes onde segurança é importante
#
# **Q-Learning**:
# - Quando queremos a política ótima rapidamente
# - Podemos tolerar exploração agressiva
#
# **Expected SARSA**:
# - Melhor escolha geral para TD
# - Boa estabilidade e velocidade
#
# **REINFORCE**:
# - Espaços de ação contínuos
# - Quando política estocástica é desejável
#
# **REINFORCE + Baseline**:
# - Versão melhorada do REINFORCE
# - Sempre preferível ao REINFORCE puro
#
# **Actor-Critic**:
# - Alta dimensão / espaços contínuos
# - Atualizações online são importantes
# - Boa opção geral para deep RL
#
# ---
#
# ## 🎓 Referências
#
# - **Sutton & Barto (2018)**: Reinforcement Learning: An Introduction (2nd Ed.)
#   - Capítulo 6: Temporal-Difference Learning
#   - Capítulo 13: Policy Gradient Methods
